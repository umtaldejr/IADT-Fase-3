# %%
# !pip install unsloth --quiet
# !pip install torch --quiet

# %% [markdown]
# # Foundation Model

# %%
from unsloth import FastLanguageModel
import torch

max_seq_length = 2048 # Or you can use up to 8192!
dtype = None # None for auto detection. Supports torch.float16, bfloat16, float32.
load_in_4bit = True # Use 4bit quantization to reduce memory usage. Can be False.

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/gemma-3-27b-it", # Choose any huggingface/tiagoespinheira model
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
    # token = "hf_...", # Use this to load private models.
)
# Out:
# ==((====))==  Unsloth 2025.9.9: Fast Gemma3 patching. Transformers: 4.56.1.
#    \\   /|    NVIDIA A100-SXM4-80GB. Num GPUs = 1. Max memory: 79.318 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.8.0+cu126. CUDA: 8.0. CUDA Toolkit: 12.6. Triton: 3.4.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.32.post2. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
from unsloth.chat_templates import get_chat_template

tokenizer = get_chat_template(
    tokenizer,
    chat_template = "gemma", # Supports zephyr, chatml, mistral, llama, alpaca, vicuna, gemma, qwen
    map_eos_token = True, # Maps <eos> to >>EOS<<
)

# %% [markdown]
# ## Prompts

# %%
messages = [
    {"role": "system", "content": "You are an AI assistant."},
    {"role": "user", "content": "What is Super Glue HT2 HandiTAK Reusable Adhesive?"},
]

text = tokenizer.apply_chat_template(
    messages,
    add_generation_prompt = True, # Must add for generation
)

from transformers import TextStreamer
_ = model.generate(
    **tokenizer([text], return_tensors = "pt").to("cuda"),
    max_new_tokens = 512, # Increase for longer outputs!
    # Recommended Gemma-3 settings!
    temperature = 1.0, top_p = 0.95, top_k = 64,
    streamer = TextStreamer(tokenizer, skip_prompt = True),
)
# Out:
# Okay, here's a breakdown of Super Glue HT2 HandiTAK Reusable Adhesive, based on information available as of late 2023/early 2024:
#
# **What it is:**
#
# Super Glue HT2 HandiTAK is a *reusable*, non-drip adhesive that's marketed as an alternative to traditional super glues, tapes, and other fasteners. It's designed to bond materials together temporarily, but strongly, and then be easily removed *without damaging* the surfaces. It's often described as a "sticky tack" or a "putty-like adhesive".
#
# **Key Features & Characteristics:**
#
# *   **Reusable:** This is the biggest selling point.  You can use it multiple times. After bonding, you can peel it off and re-apply it.  The number of reuses varies depending on conditions (see "Limitations" below).
# *   **Non-Drip, Non-Run:** It's formulated to stay where you put it – less mess than liquid super glues. It's a thicker consistency.
# *   **Instant Bonding:** It provides a strong initial tack almost immediately.
# *   **Damage-Free Removal:**  Generally, it's designed to remove cleanly without leaving residue or damaging the bonded surfaces (though this isn’t *always* true - see "Limitations" below).
# *   **Versatile:**  It can bond a wide range of materials, including:
#     *   Wood
#     *   Metal
#     *   Plastic
#     *   Ceramic
#     *   Glass
#     *   Fabric
#     *   Paper
#     *   Drywall
#     *   Tile
# *   **Available Forms:** Commonly available in tubes or sticks.
# * **Temperature Resistant:** It is more heat resistant than typical super glues.
#
#
# **Common Uses:**
#
# *   **Hanging Decorations:**  Lightweight decorations, posters, pictures, holiday ornaments. This is a *very* common use.
# *   **Temporary Fixes:** Holding things in place while glue dries, making temporary repairs.
# *   **Crafts & DIY Projects:** Various crafting applications where repositioning is needed.
# *   **Home Organization:** Securing items in place temporarily.
# *   **Mounting:** Mounting lightweight items.
#
#
#
#
# **Limitations & Things to Consider:**
#
# *   **Weight Limit:** It's not designed for heavy items. It's best for lightweight materials

# %%
messages = [
    {"role": "system", "content": "You are an AI assistant."},
    {"role": "user", "content": "What are the benefits of Tell me about OSEA - Ocean Cleanser?"},
]

text = tokenizer.apply_chat_template(
    messages,
    add_generation_prompt = True, # Must add for generation
)

from transformers import TextStreamer
_ = model.generate(
    **tokenizer([text], return_tensors = "pt").to("cuda"),
    max_new_tokens = 512, # Increase for longer outputs!
    # Recommended Gemma-3 settings!
    temperature = 1.0, top_p = 0.95, top_k = 64,
    streamer = TextStreamer(tokenizer, skip_prompt = True),
)
# Out:
# Okay, let's dive into the benefits of OSEA Ocean Cleanser! Here's a breakdown, covering what it *is*, who it's good for, and the advantages it offers, broken down into sections for clarity.  I'll also indicate where you can find more information at the end.
#
# **What *is* OSEA Ocean Cleanser?**
#
# OSEA Ocean Cleanser is a gel-based facial cleanser formulated with organic, sustainably-sourced seaweed and botanical ingredients. It's a cornerstone product in the OSEA line, known for their commitment to ocean-derived skincare.  It's designed to be a gentle yet effective daily cleanser for most skin types.  It's *not* foaming, relying instead on emulsification to lift away dirt and makeup.
#
# **Key Ingredients & What They Do:**
#
# *   **Organic Seaweed:**  OSEA uses various types of seaweed (like Gigartina Stellata and Macrocystis Pyrifera). Seaweed is incredibly rich in vitamins (A, C, E, K, and B vitamins), minerals (iodine, calcium, magnesium), and amino acids. These contribute to:
#     *   **Hydration:** Seaweed is a humectant, meaning it draws moisture *to* the skin.
#     *   **Nutrient Delivery:** Provides essential nutrients that skin needs to thrive.
#     *   **Antioxidant Protection:** Helps combat free radical damage from pollution and environmental stressors.
#     *   **Soothing:** Calms inflammation and irritation.
# *   **Aloe Vera:**  A classic soothing and hydrating ingredient. Helps to calm redness and irritation, and is good for sensitive skin.
# *   **Organic Sunflower Oil:** Provides essential fatty acids and vitamin E, helping to nourish and soften the skin. It's surprisingly good for oily skin as it doesn't clog pores.
# *   **Japanese Green Tea:**  Another powerful antioxidant, protecting against environmental damage.  Also has anti-inflammatory properties.
# * **Essential Oils (Lavender, Chamomile, etc.):**  Contribute to the scent and also offer calming and potentially balancing benefits.
#
# **Benefits - What does it *do* for your skin?**
#
# Here's a breakdown of the benefits, categorized:
#
# *   **Gentle & Effective Cleansing:**  It effectively removes makeup, dirt, and impurities without stripping the skin of its natural oils. This is a huge benefit, as many cleansers *over

# %%
messages = [
    {"role": "system", "content": "You are an AI assistant."},
    {"role": "user", "content": "What is Gifts & Decor Solar Powered Outdoor Garden Lighthouse?"},
]

text = tokenizer.apply_chat_template(
    messages,
    add_generation_prompt = True, # Must add for generation
)

from transformers import TextStreamer
_ = model.generate(
    **tokenizer([text], return_tensors = "pt").to("cuda"),
    max_new_tokens = 512, # Increase for longer outputs!
    # Recommended Gemma-3 settings!
    temperature = 1.0, top_p = 0.95, top_k = 64,
    streamer = TextStreamer(tokenizer, skip_prompt = True),
)
# Out:
# Okay, let's break down what a "Gifts & Decor Solar Powered Outdoor Garden Lighthouse" is! It's pretty much what it sounds like - a decorative lighthouse for your garden that runs on solar power. Here's a more detailed explanation:
#
# **What it is:**
#
# * **Decorative Item:** Primarily, it's a garden ornament meant to add a nautical or coastal theme to your outdoor space. They come in various sizes and levels of detail, from fairly simple to quite elaborate.
# * **Lighthouse Shape:** They are designed to *look* like a lighthouse, often with a tower shape, a "lantern room" at the top, and sometimes even a balcony or other architectural features.
# * **Solar Powered:** This is the key feature!  Instead of needing to be plugged in, they have a small solar panel (usually on top of the lantern room) that charges a battery during the day.
# * **LED Light:**  The charged battery powers an LED light inside the "lantern room."  This light typically turns on automatically at dusk and turns off at dawn. The light often has a flickering effect to simulate the beam of a real lighthouse.
# * **Outdoor Use:** They are built to withstand outdoor conditions (rain, sun, etc.), though the level of durability can vary by price and quality.
#
# **Key Features & What You Can Expect:**
#
# * **Automatic Operation:** A big convenience is that they usually turn on and off automatically based on light levels.
# * **No Wiring Needed:** Being solar-powered means no need to run electrical cords, making placement flexible.
# * **Weather Resistant:** Most are made from plastic or resin to be weather-resistant, but check the product description for details. Some cheaper models might not hold up as well in harsh weather.
# * **Varying Sizes:** You can find them anywhere from a foot tall to several feet tall.
# * **Different Styles:**  They can range in style from rustic and weathered-looking to more modern and polished.
# * **Materials:** Common materials include:
#     * **Resin:**  A durable plastic-like material, often molded to look like stone.  Very common.
#     * **Metal:** Some may have metal accents or be made primarily of metal (often with a protective coating).
#     * **Plastic:**  Cheaper models are often made entirely of plastic.
#
#
#
# **Where you'd use it:**
#
# * **Gardens:** Obvious! Placed amongst flowers

# %% [markdown]
# # Foundation Model

# %%
from unsloth import FastLanguageModel
import torch

max_seq_length = 2048 # Or you can use up to 8192!
dtype = None # None for auto detection. Supports torch.float16, bfloat16, float32.
load_in_4bit = True # Use 4bit quantization to reduce memory usage. Can be False.

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "umtaldejr/iadt-fase-3-finetune", # Choose any huggingface/tiagoespinheira model
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
    # token = "hf_...", # Use this to load private models.
)
# Out:
# ==((====))==  Unsloth 2025.9.9: Fast Gemma3 patching. Transformers: 4.56.1.
#    \\   /|    NVIDIA A100-SXM4-80GB. Num GPUs = 1. Max memory: 79.318 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.8.0+cu126. CUDA: 8.0. CUDA Toolkit: 12.6. Triton: 3.4.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.32.post2. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Loading checkpoint shards:   0%|          | 0/12 [00:00<?, ?it/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
from unsloth.chat_templates import get_chat_template

tokenizer = get_chat_template(
    tokenizer,
    chat_template = "gemma", # Supports zephyr, chatml, mistral, llama, alpaca, vicuna, gemma, qwen
    map_eos_token = True, # Maps <eos> to >>EOS<<
)

# %% [markdown]
# ## Prompts

# %%
messages = [
    {"role": "system", "content": "You are a AI assistant."},
    {"role": "user", "content": "What is Super Glue HT2 HandiTAK Reusable Adhesive?"},
]

text = tokenizer.apply_chat_template(
    messages,
    add_generation_prompt = True, # Must add for generation
)

from transformers import TextStreamer
_ = model.generate(
    **tokenizer([text], return_tensors = "pt").to("cuda"),
    max_new_tokens = 512, # Increase for longer outputs!
    # Recommended Gemma-3 settings!
    temperature = 1.0, top_p = 0.95, top_k = 64,
    streamer = TextStreamer(tokenizer, skip_prompt = True),
)
# Out:
# Here's what I can tell you about Super Glue HT2 HandiTAK Reusable Adhesive:
#
# HandiTAK is a reusable adhesive that is great for hanging posters, pictures, and other items around the house. It is also great for holding items in place while you work on them. HandiTAK is a clear, non-toxic, and non-staining adhesive that is easy to use. Simply roll the adhesive onto the back of the item you want to hang, then press it against the wall. HandiTAK will hold the item in place for up to 6 months, but it can be removed at any time without damaging the wall or the item. HandiTAK is a great way to hang items around the house without having to use nails or screws. It is also a great way to hold items in place while you work on them.<end_of_turn>

# %%
messages = [
    {"role": "system", "content": "You are an AI assistant."},
    {"role": "user", "content": "What are the benefits of Tell me about OSEA - Ocean Cleanser?"},
]

text = tokenizer.apply_chat_template(
    messages,
    add_generation_prompt = True, # Must add for generation
)

from transformers import TextStreamer
_ = model.generate(
    **tokenizer([text], return_tensors = "pt").to("cuda"),
    max_new_tokens = 512, # Increase for longer outputs!
    # Recommended Gemma-3 settings!
    temperature = 1.0, top_p = 0.95, top_k = 64,
    streamer = TextStreamer(tokenizer, skip_prompt = True),
)
# Out:
# Here's what I can tell you about OSEA - Ocean Cleanser:
#
# This gentle, yet effective cleanser is ideal for all skin types. It is a unique blend of marine algae, seaweed, and essential oils that gently cleanses and exfoliates the skin. The cleanser is enriched with Vitamin E and Vitamin C to help protect the skin from free radicals.<end_of_turn>

# %%
messages = [
    {"role": "system", "content": "You are an AI assistant."},
    {"role": "user", "content": "What is Gifts & Decor Solar Powered Outdoor Garden Lighthouse?"},
]

text = tokenizer.apply_chat_template(
    messages,
    add_generation_prompt = True, # Must add for generation
)

from transformers import TextStreamer
_ = model.generate(
    **tokenizer([text], return_tensors = "pt").to("cuda"),
    max_new_tokens = 512, # Increase for longer outputs!
    # Recommended Gemma-3 settings!
    temperature = 1.0, top_p = 0.95, top_k = 64,
    streamer = TextStreamer(tokenizer, skip_prompt = True),
)
# Out:
# Here's what I can tell you about Gifts & Decor Solar Powered Outdoor Garden Lighthouse:
#
# This solar powered lighthouse is a great addition to any garden. The lighthouse is made of durable plastic and is designed to withstand the elements. The lighthouse is powered by a solar panel on the top of the lighthouse. The lighthouse will light up automatically at night and turn off during the day. The lighthouse is 24 inches tall.<end_of_turn>

# %% [markdown]
# # Gradio

# %%
def get_model_responses(prompt):
    messages = [
        {"role": "system", "content": "You are an AI assistant."},
        {"role": "user", "content": prompt},
    ]

    text_model1 = tokenizer.apply_chat_template(
        messages,
        add_generation_prompt = True,
    )
    inputs_model1 = tokenizer([text_model1], return_tensors = "pt").to("cuda")
    output_model1 = model.generate(
        **inputs_model1,
        max_new_tokens = 512,
        temperature = 1.0,
        top_p = 0.95,
        top_k = 64,
        do_sample = True,
    )
    response_model1 = tokenizer.decode(output_model1[0], skip_special_tokens=True)
    response_model1 = response_model1.replace(text_model1, "").strip()


    text_model2 = tokenizer.apply_chat_template(
        messages,
        add_generation_prompt = True,
    )
    inputs_model2 = tokenizer([text_model2], return_tensors = "pt").to("cuda")
    output_model2 = model.generate(
        **inputs_model2,
        max_new_tokens = 128,
        temperature = 1.0,
        top_p = 0.95,
        top_k = 64,
        do_sample = True,
    )
    response_model2 = tokenizer.decode(output_model2[0], skip_special_tokens=True)
    response_model2 = response_model2.replace(text_model2, "").strip()

    return response_model1, response_model2

# %%
import gradio as gr

interface = gr.Interface(
    fn=get_model_responses,
    inputs=gr.Textbox(label="Enter your prompt:"),
    outputs=[
        gr.Textbox(label="Response from unsloth/gemma-3-27b-it:"),
        gr.Textbox(label="Response from umtaldejr/iadt-fase-3-finetune:")
    ],
    title="Model Response Comparison",
    description="Compare responses from two different language models.",
)

# %%
interface.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://1e02359f89d46db0a5.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://1e02359f89d46db0a5.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
